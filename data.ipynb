# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("bmw.csv")

# %%
display(df)
# Out:
#            model  year  price transmission  mileage fuelType   mpg  engineSize
# 0       5 Series  2014  11200    Automatic    67068   Diesel  57.6         2.0
# 1       6 Series  2018  27000    Automatic    14827   Petrol  42.8         2.0
# 2       5 Series  2016  16000    Automatic    62794   Diesel  51.4         3.0
# 3       1 Series  2017  12750    Automatic    26676   Diesel  72.4         1.5
# 4       7 Series  2014  14500    Automatic    39554   Diesel  50.4         3.0
# ...          ...   ...    ...          ...      ...      ...   ...         ...
# 10776         X3  2016  19000    Automatic    40818   Diesel  54.3         2.0
# 10777   5 Series  2016  14600    Automatic    42947   Diesel  60.1         2.0
# 10778   3 Series  2017  13100       Manual    25468   Petrol  42.8         2.0
# 10779   1 Series  2014   9930    Automatic    45000   Diesel  64.2         2.0
# 10780         X1  2017  15981    Automatic    59432   Diesel  57.6         2.0
#
# ...

# %%
df.head()
# Out:
#        model  year  price transmission  mileage fuelType   mpg  engineSize
# 0   5 Series  2014  11200    Automatic    67068   Diesel  57.6         2.0
# 1   6 Series  2018  27000    Automatic    14827   Petrol  42.8         2.0
# 2   5 Series  2016  16000    Automatic    62794   Diesel  51.4         3.0
# 3   1 Series  2017  12750    Automatic    26676   Diesel  72.4         1.5
# 4   7 Series  2014  14500    Automatic    39554   Diesel  50.4         3.0

# %%
df.tail()
# Out:
#            model  year  price transmission  mileage fuelType   mpg  engineSize
# 10776         X3  2016  19000    Automatic    40818   Diesel  54.3         2.0
# 10777   5 Series  2016  14600    Automatic    42947   Diesel  60.1         2.0
# 10778   3 Series  2017  13100       Manual    25468   Petrol  42.8         2.0
# 10779   1 Series  2014   9930    Automatic    45000   Diesel  64.2         2.0
# 10780         X1  2017  15981    Automatic    59432   Diesel  57.6         2.0

# %%
df.shape
# Out:
# (10781, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10781 non-null  object
#  1   year          10781 non-null  int64
#  2   price         10781 non-null  int64
#  3   transmission  10781 non-null  object
#  4   mileage       10781 non-null  int64
#  5   fuelType      10781 non-null  object
#  6   mpg           10781 non-null  float64
#  7   engineSize    10781 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 673.9+ KB

# %%
df['model'].value_counts()
# Out:
# model
# 3 Series    2443
# 1 Series    1969
# 2 Series    1229
# 5 Series    1056
# 4 Series     995
# X1           804
# X3           551
# X5           468
# X2           288
# X4           179
# M4           125
# 6 Series     108
# Z4           108
# 7 Series     106
# X6           106
# X7            55
# i3            43
# 8 Series      39
# M5            29
# M3            27
# M2            21
# i8            17
# M6             8
# Z3             7
# Name: count, dtype: int64

# %%
df['transmission'].value_counts()
# Out:
# transmission
# Semi-Auto    4666
# Automatic    3588
# Manual       2527
# Name: count, dtype: int64

# %%
df['transmission'].value_counts()
# Out:
# fuelType
# Diesel      7027
# Petrol      3417
# Hybrid       298
# Other         36
# Electric       3
# Name: count, dtype: int64

# %%
df['transmission'].value_counts().plot(kind='pie', autopct = '%1.1f%%', startangle = 90)
plt.title("Transmission systems in BMW used car ")
plt.ylabel("")
plt.show()

# %%
df['transmission'].value_counts().plot(kind='pie', autopct = '%1.1f%%', startangle = 90)
plt.title("transmission in BMW used car ")
plt.ylabel("")
plt.show()

# %%
df['transmission'].value_counts().plot(kind='bar')
plt.title("transmission in BMW used car ")
plt.ylabel("")
plt.show()

# %%
df['year'].value_counts()
# Out:
# year
# 2019    3485
# 2016    1882
# 2017    1721
# 2015     922
# 2018     848
# 2020     733
# 2014     501
# 2013     357
# 2012     119
# 2011      51
# 2010      41
# 2009      30
# 2008      23
# 2007      16
# 2006      14
# 2004      12
# 2002       6
# 2005       6
# 1999       4
# 2001       3
# 2003       2
# 2000       2
# 1996       1
# 1997       1
# 1998       1
# Name: count, dtype: int64

# %%
fueltype_count = df['fuelType'].value_counts(normalize = True)
#display(fueltype_count)
#print(type(fueltype_count))


fueltype_count = pd.DataFrame(fueltype_count)
#print(type(fueltype_count))
#display(fueltype_count)



# fueltype_count = fueltype_count.reset_index()
#display(fueltype_count)



# fueltype_count = fueltype_count.rename(columns={'fuelType':'fuelType', 'proportion':'% of car'})
# display(fueltype_count)


# fueltype_count = fueltype_count['% of car']*100
#display(fueltype_count)
fueltype_count['proportion'] = fueltype_count['proportion']*100


# fueltype_count["% of car"]= fueltype_count["% of car"].round(2)
# display(fueltype_count)


fueltype_count= fueltype_count.round(2)
display(fueltype_count)
# Out:
#           proportion
# fuelType
# Diesel         65.18
# Petrol         31.69
# Hybrid          2.76
# Other           0.33
# Electric        0.03

# %% [markdown]
# **Generate bar plot for transmission**

# %%
sns.barplot(x='transmission', y = 'proportion', data = transmission_count, color='orange')
plt.title('transmission ')
plt.yticks(np.arange(0,101,20))
plt.show()

# %% [markdown]
# ** Create bar plot for the transmission**

# %%
transmission_count = df['transmission'].value_counts(normalize = True)
#display(transmission_count)
#print(type(transmission_count))


transmission_count = pd.DataFrame(transmission_count)
#print(type(transmission_count))
#display(transmission_count)

# transmission_count = transmission_count.reset_index()
#display(transmission_count)

# transmission_count = transmission_count.rename(columns={'transmission':'transmission', 'proportion':'% of car'})
# display(transmission_count)


# transmission_count = transmission_count['% of car']*100
#display(transmission_count)
transmission_count['proportion'] = transmission_count['proportion']*100

# transmission_count["% of car"]= transmission_count["% of car"].round(2)
# display(transmission_count)

transmission_count= transmission_count.round(2)
display(transmission_count)
# Out:
#               proportion
# transmission
# Semi-Auto          43.28
# Automatic          33.28
# Manual             23.44

# %%
sns.barplot(x='transmission', y = 'proportion', data = transmission_count, color='blue')
plt.title('transmission ')
plt.yticks(np.arange(0,101,20))
plt.show()

# %% [markdown]
# ** Create bar plot for model **

# %%
model_count = df['model'].value_counts(normalize = True)
#display(transmission_count)
#print(type(transmission_count))


model_count = pd.DataFrame(model_count)
#print(type(transmission_count))
#display(transmission_count)

# transmission_count = transmission_count.reset_index()
#display(transmission_count)

# transmission_count = transmission_count.rename(columns={'transmission':'transmission', 'proportion':'% of car'})
# display(transmission_count)


# model_count = transmission_count['% of car']*100
#display(transmission_count)
model_count['proportion'] = model_count['proportion']*100

# model_count["% of car"]= model_count["% of car"].round(2)
# display(model_count)

model_count= model_count.round(2)
display(model_count)
# Out:
#           proportion
# model
# 3 Series       22.66
# 1 Series       18.26
# 2 Series       11.40
# 5 Series        9.80
# 4 Series        9.23
# X1              7.46
# X3              5.11
# X5              4.34
# X2              2.67
# X4              1.66
# M4              1.16
# 6 Series        1.00
# Z4              1.00
# 7 Series        0.98
# X6              0.98
# X7              0.51
# i3              0.40
# 8 Series        0.36
# M5              0.27
# M3              0.25
# M2              0.19
# i8              0.16
# M6              0.07
# Z3              0.06

# %%
sns.barplot(x='model', y = 'proportion', data = model_count, color='blue')
plt.title('Model ')
plt.yticks(np.arange(0,31,5))
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,9))

plt.subplot(1,3,1)
sns.barplot(x='transmission', y = 'proportion', data = transmission_count, color='orange')
plt.title('transmission ')
plt.yticks(np.arange(0,71,20))

plt.subplot(1,3,2)
sns.barplot(x='transmission', y = 'proportion', data = transmission_count, color='blue')
plt.title('transmission ')
plt.yticks(np.arange(0,71,20))


plt.subplot(1,3,3)
sns.barplot(x='model', y = 'proportion', data = model_count, color='blue')
plt.title('Model ')
plt.yticks(np.arange(0,71,5))
plt.xticks(rotation=90)


plt.show()

# %%
def uniquie_percent_count(data, col):
    col_count = data[col].value_counts(normalize = True)
    col_count = pd.DataFrame(col_count)
    col_count = col_count.reset_index()
    col_count = col_count.rename(columns={col:col, 'proportion':'percentage_of_car'})
    col_count['percentage_of_car'] = col_count['percentage_of_car']*100
    col_count['percentage_of_car']= col_count["percentage_of_car"].round(2)
    return col_count

# %%
fuelType_count = uniquie_percent_count(df, 'fuelType')
display(fuelType_count)
# Out:
#    fuelType  percentage_of_car
# 0    Diesel              65.18
# 1    Petrol              31.69
# 2    Hybrid               2.76
# 3     Other               0.33
# 4  Electric               0.03

# %%
transmission_count = uniquie_percent_count(df, 'transmission')
display(transimission_count)
# Out:
#   transmission  percentage_of_car
# 0    Semi-Auto              43.28
# 1    Automatic              33.28
# 2       Manual              23.44

# %%
model_count = uniquie_percent_count(df, 'model')
display(model_count)
# Out:
#         model  percentage_of_car
# 0    3 Series              22.66
# 1    1 Series              18.26
# 2    2 Series              11.40
# 3    5 Series               9.80
# 4    4 Series               9.23
# 5          X1               7.46
# 6          X3               5.11
# 7          X5               4.34
# 8          X2               2.67
# 9          X4               1.66
# 10         M4               1.16
# 11   6 Series               1.00
# 12         Z4               1.00
# 13   7 Series               0.98
# 14         X6               0.98
# 15         X7               0.51
# 16         i3               0.40
# 17   8 Series               0.36
# 18         M5               0.27
# 19         M3               0.25
# 20         M2               0.19
# 21         i8               0.16
# 22         M6               0.07
# 23         Z3               0.06

# %%
year_count = uniquie_percent_count(df, 'year')
year_count = year_count.sort_values(by='year')
display(year_count)
# Out:
#     year  percentage_of_car
# 22  1996               0.01
# 23  1997               0.01
# 24  1998               0.01
# 18  1999               0.04
# 21  2000               0.02
# 19  2001               0.03
# 16  2002               0.06
# 20  2003               0.02
# 15  2004               0.11
# 17  2005               0.06
# 14  2006               0.13
# 13  2007               0.15
# 12  2008               0.21
# 11  2009               0.28
# 10  2010               0.38
# 9   2011               0.47
# 8   2012               1.10
# 7   2013               3.31
# 6   2014               4.65
# 3   2015               8.55
# 1   2016              17.46
# 2   2017              15.96
# 4   2018               7.87
# 0   2019              32.33
# 5   2020               6.80

# %%
def barplot(data, x_col, y_col, color, yticks, rotation):
    sns.barplot(x= x_col, y = y_col, data = data, color= color)
    plt.title('percentage of car presenet for each '+ 'x_col')
    plt.yticks(yticks)
    plt.xticks(rotation = rotation)

# %%
sns.set_context('paper')  #paper, talk, poster

plt.figure(figsize=(18,20))

plt.subplot(2,2,1)
barplot(model_count, 'model', 'percentage_of_car', 'orange', np.arange(0,41,20), 90)

plt.subplot(2,2,2)
barplot(year_count, 'year', 'percentage_of_car', 'black', np.arange(0,41,20), 90)

plt.subplot(2,2,3)
barplot(transmission_count, 'transmission', 'percentage_of_car', 'orange', np.arange(0,71,20), 0)

plt.subplot(2,2,4)
barplot(fuelType_count, 'fuelType', 'percentage_of_car', 'blue', np.arange(0,71,20), 0)


plt.show()
#plt.tight_layout()

# %% [markdown]
# **Scatter Plot**

# %%
plt.figure(figsize=(20,12))
plt.subplot(3,1,1)
sns.scatterplot(data=df, x='mileage', y='price')

plt.subplot(3,1,2)
sns.scatterplot(x='mpg', y='price', data=df)

plt.subplot(3,1,3)
sns.scatterplot(x='engineSize', y='price', data=df)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,12))
plt.subplot(2,2,1)
sns.scatterplot(data=df, x='mileage', y='price',)

plt.subplot(2,2,2)
sns.scatterplot(data=df, x='mileage', y='price', hue='transmission')

plt.subplot(2,2,3)
sns.scatterplot(data=df, x='mileage', y='price', hue='fuelType')

plt.subplot(2,2,4)
sns.scatterplot(data=df, x='mileage', y='price', hue='model')


plt.tight_layout()
plt.show()

# %% [markdown]
# Creating trend line

# %%
plt.figure(figsize=(20,12))
plt.subplot(3,1,1)
sns.regplot(data=df, x='mileage', y='price', color='r')

plt.subplot(3,1,2)
sns.regplot(data=df, x='mileage', y='price', line_kws={'color':'r'})

plt.subplot(3,1,3)
sns.regplot(data=df, x='mileage', y='price', scatter_kws={'color':'r', 'edgecolor':'white'})

plt.tight_layout()
plt.show()

# %% [markdown]
# pairplot

# %%
plt.figure(figsize=(16,12))
sns.pairplot(df, corner=True, hue='transmission')
plt.show()

# %% [markdown]
# Also there are many types of scatter plot. For more details pls follow the sns website line.
